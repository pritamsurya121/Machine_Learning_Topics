# %%
# Supress Warnings

import warnings
warnings.filterwarnings('ignore')

# %%
# Import the numpy and pandas packages

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt  #Here also importing matplotlib and seaborn that will be using to plot the scatter & bar plot. 
import seaborn as sns

# %% [markdown]
# ## Task 1: Reading and Inspection
#
# -  ### Subtask 1.1: Import and read
#
# Import and read the movie database. Store it in a variable called `movies`.

# %%
movies = pd.read_csv("Movie+Assignment+Data.csv")# Write your code for importing the csv file here
movies   #importing csv file using pd.read_csv() method and storing in variable "movies".
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 5038  Color        Scott Smith                     1.0      87.0
# 5039  Color                NaN                    43.0      43.0
# 5040  Color   Benjamin Roberds                    13.0      76.0
# 5041  Color        Daniel Hsia                    14.0     100.0
# 5042  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# ...

# %% [markdown]
# -  ### Subtask 1.2: Inspect the dataframe
#
# Inspect the dataframe's columns, shapes, variable types etc.

# %%
# Write your code for inspection here
movies.info()  #this is dataframe methods to defines class ,memory usage, index types and total columns of the movies dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5043 entries, 0 to 5042
# Data columns (total 28 columns):
# color                        5024 non-null object
# director_name                4939 non-null object
# num_critic_for_reviews       4993 non-null float64
# duration                     5028 non-null float64
# director_facebook_likes      4939 non-null float64
# actor_3_facebook_likes       5020 non-null float64
# actor_2_name                 5030 non-null object
# actor_1_facebook_likes       5036 non-null float64
# gross                        4159 non-null float64
# genres                       5043 non-null object
# actor_1_name                 5036 non-null object
# movie_title                  5043 non-null object
# num_voted_users              5043 non-null int64
# cast_total_facebook_likes    5043 non-null int64
# actor_3_name                 5020 non-null object
# facenumber_in_poster         5030 non-null float64
# ...

# %%
movies.dtypes  #this methods shows series of all the column name with their datatypes present in movies dataframe
# Out:
# color                         object
# director_name                 object
# num_critic_for_reviews       float64
# duration                     float64
# director_facebook_likes      float64
# actor_3_facebook_likes       float64
# actor_2_name                  object
# actor_1_facebook_likes       float64
# gross                        float64
# genres                        object
# actor_1_name                  object
# movie_title                   object
# num_voted_users                int64
# cast_total_facebook_likes      int64
# actor_3_name                  object
# facenumber_in_poster         float64
# plot_keywords                 object
# movie_imdb_link               object
# num_user_for_reviews         float64
# language                      object
# country                       object
# content_rating                object
# budget                       float64
# title_year                   float64
# actor_2_facebook_likes       float64
# ...

# %%
movies.describe  #this method shows column names with head and tail records of dataframe column
# Out:
# <bound method NDFrame.describe of       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 5038  Color        Scott Smith                     1.0      87.0
# 5039  Color                NaN                    43.0      43.0
# 5040  Color   Benjamin Roberds                    13.0      76.0
# 5041  Color        Daniel Hsia                    14.0     100.0
# 5042  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# ...

# %%
movies.shape  #(5043,28) = (no. of rows, no. of columns) this shpae method of dataframe stores no. of rows and 
#columns of dataframe in tuple form.
# Out:
# (5043, 28)

# %%
movies.columns  #shows list of all the available columns present in IMDb movie dataframe
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %% [markdown]
# ## Task 2: Cleaning the Data
#
# -  ### Subtask 2.1: Inspect Null values
#
# Find out the number of Null values in all the columns and rows. Also, find the percentage of Null values in each column. Round off the percentages upto two decimal places.

# %%
# Write your code for column-wise null count here
#movies.isnull().sum(axis=0) this will also shows same result as axis=0 is default for column
movies.isnull().sum()
# Out:
# color                         19
# director_name                104
# num_critic_for_reviews        50
# duration                      15
# director_facebook_likes      104
# actor_3_facebook_likes        23
# actor_2_name                  13
# actor_1_facebook_likes         7
# gross                        884
# genres                         0
# actor_1_name                   7
# movie_title                    0
# num_voted_users                0
# cast_total_facebook_likes      0
# actor_3_name                  23
# facenumber_in_poster          13
# plot_keywords                153
# movie_imdb_link                0
# num_user_for_reviews          21
# language                      12
# country                        5
# content_rating               303
# budget                       492
# title_year                   108
# actor_2_facebook_likes        13
# imdb_score                     0
# aspect_ratio                 329
# movie_facebook_likes           0
# dtype: int64

# %%
# Write your code for row-wise null count here
#axis=1 is for to check row-wise null count
movies.isnull().sum(axis=1)
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4       14
#         ..
# 5038     4
# 5039     5
# 5040     4
# 5041     2
# 5042     0
# Length: 5043, dtype: int64

# %%
len(movies.index)  #find total length/no. of rows of available in movies dataframe
# Out:
# 5043

# %%
# Write your code for column-wise null percentages here
#use innull() function to detect the missing values and summing it. missing value divides into length of rows/index and use round() function upto 2 decimal to find out percentage.
#isnull() return a boolean values. Returns true if value is missing otherwise False.
round(100*(movies.isnull().sum(axis=0)/len(movies.index)),2)
# Out:
# color                         0.38
# director_name                 2.06
# num_critic_for_reviews        0.99
# duration                      0.30
# director_facebook_likes       2.06
# actor_3_facebook_likes        0.46
# actor_2_name                  0.26
# actor_1_facebook_likes        0.14
# gross                        17.53
# genres                        0.00
# actor_1_name                  0.14
# movie_title                   0.00
# num_voted_users               0.00
# cast_total_facebook_likes     0.00
# actor_3_name                  0.46
# facenumber_in_poster          0.26
# plot_keywords                 3.03
# movie_imdb_link               0.00
# num_user_for_reviews          0.42
# language                      0.24
# country                       0.10
# content_rating                6.01
# budget                        9.76
# title_year                    2.14
# actor_2_facebook_likes        0.26
# imdb_score                    0.00
# aspect_ratio                  6.52
# ...

# %% [markdown]
# -  ### Subtask 2.2: Drop unecessary columns
#
# For this assignment, you will mostly be analyzing the movies with respect to the ratings, gross collection, popularity of movies, etc. So many of the columns in this dataframe are not required. So it is advised to drop the following columns.
# -  color
# -  director_facebook_likes
# -  actor_1_facebook_likes
# -  actor_2_facebook_likes
# -  actor_3_facebook_likes
# -  actor_2_name
# -  cast_total_facebook_likes
# -  actor_3_name
# -  duration
# -  facenumber_in_poster
# -  content_rating
# -  country
# -  movie_imdb_link
# -  aspect_ratio
# -  plot_keywords

# %%
# Write your code for dropping the columns here. It is advised to keep inspecting the dataframe after each set of operations 
#Using drop() method of pandas dataframe.Here I am dropping columns based on index of column and performing inplace operation.
#We can use loc and iloc function also but here not possible as I thought it is difficult to put column 
#name/index because we are not dropping columns in order.
#We can use columns name also in drop method but not sure why inplace operation didn't working.
movies.drop(movies.columns[[0,3,4,5,6,7,13,14,15,16,17,20,21,24,26]], axis = 1, inplace = True) 
movies
# Out:
#           director_name  num_critic_for_reviews        gross  \
# 0         James Cameron                   723.0  760505847.0
# 1        Gore Verbinski                   302.0  309404152.0
# 2            Sam Mendes                   602.0  200074175.0
# 3     Christopher Nolan                   813.0  448130642.0
# 4           Doug Walker                     NaN          NaN
# ...                 ...                     ...          ...
# 5038        Scott Smith                     1.0          NaN
# 5039                NaN                    43.0          NaN
# 5040   Benjamin Roberds                    13.0          NaN
# 5041        Daniel Hsia                    14.0      10443.0
# 5042           Jon Gunn                    43.0      85222.0
#
#                                genres     actor_1_name  \
# 0     Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1            Action|Adventure|Fantasy      Johnny Depp
# 2           Action|Adventure|Thriller  Christoph Waltz
# ...

# %%
round(100*(movies.isnull().sum()/len(movies.index)),2)  
#to check again null count in percentage after dropping above columns and still we have gross and budget has more NaN %ge.
# Out:
# director_name              2.06
# num_critic_for_reviews     0.99
# gross                     17.53
# genres                     0.00
# actor_1_name               0.14
# movie_title                0.00
# num_voted_users            0.00
# num_user_for_reviews       0.42
# language                   0.24
# budget                     9.76
# title_year                 2.14
# imdb_score                 0.00
# movie_facebook_likes       0.00
# dtype: float64

# %% [markdown]
# -  ### Subtask 2.3: Drop unecessary rows using columns with high Null percentages
#
# Now, on inspection you might notice that some columns have large percentage (greater than 5%) of Null values. Drop all the rows which have Null values for such columns.

# %%
# Write your code for dropping the rows here
#to check how many rows having null values greater than 5
movies[movies.isnull().sum(axis=1)>5]
# Out:
#             director_name  num_critic_for_reviews  gross  \
# 4             Doug Walker                     NaN    NaN
# 279   Christopher Barnard                     NaN    NaN
# 2342                  NaN                     NaN    NaN
# 2370                  NaN                     NaN    NaN
#
#                                genres             actor_1_name  \
# 4                         Documentary              Doug Walker
# 279                            Comedy              Mathew Buck
# 2342                     Drama|Family            Peter Vaughan
# 2370  Comedy|Drama|Reality-TV|Romance  Nicole 'Snooki' Polizzi
#
#                                             movie_title  num_voted_users  \
# 4     Star Wars: Episode VII - The Force Awakens    ...                8
# 279                            10,000 B.C.                             6
# 2342                    The Doombolt Chase                            18
# ...

# %%
len(movies[movies.isnull().sum(axis=1) > 5].index) #find total number of columns which are having null values greater than 5
# Out:
# 4

# %%
# 4 rows have more than 5 missing values
# calculate the percentage
100*(len(movies[movies.isnull().sum(axis=1) > 5].index) / len(movies.index))
# Out:
# 0.07931786634939521

# %%
# retaining the rows having <= 5 NaNs
movies = movies[movies.isnull().sum(axis=1) <= 5]

# look at the summary again post removal of NaN values 
round(100*(movies.isnull().sum()/len(movies.index)), 2)
# Out:
# director_name              2.02
# num_critic_for_reviews     0.91
# gross                     17.46
# genres                     0.00
# actor_1_name               0.14
# movie_title                0.00
# num_voted_users            0.00
# num_user_for_reviews       0.34
# language                   0.20
# budget                     9.68
# title_year                 2.06
# imdb_score                 0.00
# movie_facebook_likes       0.00
# dtype: float64

# %%
#As per above result we have gross and budget columns has greater than 5% of Null values, 
#lets drop NaN values from both columns
#use pd.isnull() method to remove the Null values from gross and budget columns
#Calculate the percentage again after removing NaN values from gross and budget columns of movies dataframe.
movies = movies[~pd.isnull(movies['gross'])]  
movies = movies[~pd.isnull(movies['budget'])]  
round(100*(movies.isnull().sum()/len(movies.index)), 2)
# Out:
# director_name             0.00
# num_critic_for_reviews    0.03
# gross                     0.00
# genres                    0.00
# actor_1_name              0.08
# movie_title               0.00
# num_voted_users           0.00
# num_user_for_reviews      0.00
# language                  0.08
# budget                    0.00
# title_year                0.00
# imdb_score                0.00
# movie_facebook_likes      0.00
# dtype: float64

# %% [markdown]
# -  ### Subtask 2.4: Fill NaN values
#
# You might notice that the `language` column has some NaN values. Here, on inspection, you will see that it is safe to replace all the missing values with `'English'`.

# %%
#to check the count of how many movies are present of each Language in movies dataframe after all above operations 
movies['language'].value_counts(sort=True)
# Out:
# English       3707
# French          37
# Spanish         26
# Mandarin        15
# German          13
# Japanese        12
# Hindi           10
# Cantonese        8
# Italian          7
# Portuguese       5
# Korean           5
# Norwegian        4
# Thai             3
# Persian          3
# Hebrew           3
# Danish           3
# Dutch            3
# Aboriginal       2
# Dari             2
# Indonesian       2
# Maya             1
# Bosnian          1
# Arabic           1
# None             1
# Icelandic        1
# Dzongkha         1
# Romanian         1
# Russian          1
# Zulu             1
# Hungarian        1
# Mongolian        1
# Filipino         1
# Czech            1
# Swedish          1
# Telugu           1
# Kazakh           1
# Aramaic          1
# Vietnamese       1
# Name: language, dtype: int64

# %%
# Write your code for filling the NaN values in the 'language' column here
#imputing the NaN values with English in Language column
#And checling the percentage again of NaN values present in each column and finally we have less %ge of NaN values.
movies['language'].fillna('English', inplace=True)  
round(100*(movies.isnull().sum()/len(movies.index)), 2)
# Out:
# director_name             0.00
# num_critic_for_reviews    0.03
# gross                     0.00
# genres                    0.00
# actor_1_name              0.08
# movie_title               0.00
# num_voted_users           0.00
# num_user_for_reviews      0.00
# language                  0.00
# budget                    0.00
# title_year                0.00
# imdb_score                0.00
# movie_facebook_likes      0.00
# dtype: float64

# %% [markdown]
# -  ### Subtask 2.5: Check the number of retained rows
#
# You might notice that two of the columns viz. `num_critic_for_reviews` and `actor_1_name` have small percentages of NaN values left. You can let these columns as it is for now. Check the number and percentage of the rows retained after completing all the tasks above.

# %%
movies.shape #shape method defines the no. of rows and columsn as a tuple
# Out:
# (3891, 13)

# %%
movies.index   #No. of rows remaining after removing NaN operation
# Out:
# Int64Index([   0,    1,    2,    3,    5,    6,    7,    8,    9,   10,
#             ...
#             5023, 5025, 5026, 5027, 5029, 5033, 5034, 5035, 5037, 5042],
#            dtype='int64', length=3891)

# %%
# Write your code for checking number of retained rows here
#calculate the no. of percentage retained after dropping columns and removing NaN values. 
#We can also calculate like round(100*(3891/5043),2)=77.16 (no.of rows present/no. of rows available in initial dataset)
#Checkpoint 1 result achieved here.
round(100 * (len(movies.index)/5043),0)
# Out:
# 77.0

# %% [markdown]
# **Checkpoint 1:** You might have noticed that we still have around `77%` of the rows!

# %% [markdown]
# ## Task 3: Data Analysis
#
# -  ### Subtask 3.1: Change the unit of columns
#
# Convert the unit of the `budget` and `gross` columns from `$` to `million $`.

# %%
# Write your code for unit conversion here -- Converting budget and gross columns in 1 millions format using apply() method on 
#columns budget and gross and result_type attributr is expand.
movies[['budget','gross']].apply(lambda x:x/1000000, axis=1,result_type='expand')
# Out:
#         budget       gross
# 0     237.0000  760.505847
# 1     300.0000  309.404152
# 2     245.0000  200.074175
# 3     250.0000  448.130642
# 5     263.7000   73.058679
# ...        ...         ...
# 5033    0.0070    0.424760
# 5034    0.0070    0.070071
# 5035    0.0070    2.040920
# 5037    0.0090    0.004584
# 5042    0.0011    0.085222
#
# [3891 rows x 2 columns]

# %% [markdown]
# -  ### Subtask 3.2: Find the movies with highest profit
#
#     1. Create a new column called `profit` which contains the difference of the two columns: `gross` and `budget`.
#     2. Sort the dataframe using the `profit` column as reference.
#     3. Plot `profit` (y-axis) vs `budget` (x- axis) and observe the outliers using the appropriate chart type.
#     4. Extract the top ten profiting movies in descending order and store them in a new dataframe - `top10`

# %%
# Write your code for creating the profit column here
#Creating profit columns which is nothing but differ. b/w gross and budget columns value
movies['profit']=movies['gross'] - movies['budget']  
movies
# Out:
#           director_name  num_critic_for_reviews        gross  \
# 0         James Cameron                   723.0  760505847.0
# 1        Gore Verbinski                   302.0  309404152.0
# 2            Sam Mendes                   602.0  200074175.0
# 3     Christopher Nolan                   813.0  448130642.0
# 5        Andrew Stanton                   462.0   73058679.0
# ...                 ...                     ...          ...
# 5033      Shane Carruth                   143.0     424760.0
# 5034   Neill Dela Llana                    35.0      70071.0
# 5035   Robert Rodriguez                    56.0    2040920.0
# 5037       Edward Burns                    14.0       4584.0
# 5042           Jon Gunn                    43.0      85222.0
#
#                                    genres     actor_1_name  \
# 0         Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1                Action|Adventure|Fantasy      Johnny Depp
# ...

# %%
# Write your code for sorting the dataframe here
movies.sort_values(by=['profit'],ascending=False)  #sort dataframe using profit column in descending order
# Out:
#          director_name  num_critic_for_reviews        gross  \
# 0        James Cameron                   723.0  760505847.0
# 29     Colin Trevorrow                   644.0  652177271.0
# 26       James Cameron                   315.0  658672302.0
# 3024      George Lucas                   282.0  460935665.0
# 3080  Steven Spielberg                   215.0  434949459.0
# ...                ...                     ...          ...
# 2334   Katsuhiro Ôtomo                   105.0     410388.0
# 2323    Hayao Miyazaki                   174.0    2298191.0
# 3005      Lajos Koltai                    73.0     195888.0
# 3859    Chan-wook Park                   202.0     211667.0
# 2988      Joon-ho Bong                   363.0    2201412.0
#
#                                                  genres         actor_1_name  \
# 0                       Action|Adventure|Fantasy|Sci-Fi          CCH Pounder
# 29                     Action|Adventure|Sci-Fi|Thriller  Bryce Dallas Howard
# ...

# %%
# Write code for profit vs budget plot here
sns.set_style("white")
plt.scatter(movies['budget'],movies['profit'], facecolors='none' , edgecolors='red')
plt.xlabel("budget")
plt.ylabel("profit")
plt.yscale('log')
plt.xscale('log')
plt.show()      #Use scatter plot and outliers value are present in budget b/w 10^3 to 10^5.

# %%
# Write your code to get the top 10 profiting movies here
#top 10 profiting movie sort based on profit column in desc order
#movie_title=The Avengers appeared 2 times in below top10 movie dataframe ,that's duplicate value here. Let's drop duplicate.
top10 = movies.sort_values("profit", ascending=False).head(10) 
top10
# Out:
#           director_name  num_critic_for_reviews        gross  \
# 0         James Cameron                   723.0  760505847.0
# 29      Colin Trevorrow                   644.0  652177271.0
# 26        James Cameron                   315.0  658672302.0
# 3024       George Lucas                   282.0  460935665.0
# 3080   Steven Spielberg                   215.0  434949459.0
# 794         Joss Whedon                   703.0  623279547.0
# 17          Joss Whedon                   703.0  623279547.0
# 509        Roger Allers                   186.0  422783777.0
# 240        George Lucas                   320.0  474544677.0
# 66    Christopher Nolan                   645.0  533316061.0
#
#                                         genres         actor_1_name  \
# 0              Action|Adventure|Fantasy|Sci-Fi          CCH Pounder
# 29            Action|Adventure|Sci-Fi|Thriller  Bryce Dallas Howard
# 26                               Drama|Romance    Leonardo DiCaprio
# ...

# %% [markdown]
# -  ### Subtask 3.3: Drop duplicate values
#
# After you found out the top 10 profiting movies, you might have noticed a duplicate value. So, it seems like the dataframe has duplicate values as well. Drop the duplicate values from the dataframe and repeat `Subtask 3.2`. Note that the same `movie_title` can be there in different languages.

# %%
# Write your code for dropping duplicate values here
movies.drop_duplicates(inplace=True)   #dropping duplicates rows from the movie dataset.
movies
# Out:
#           director_name  num_critic_for_reviews        gross  \
# 0         James Cameron                   723.0  760505847.0
# 1        Gore Verbinski                   302.0  309404152.0
# 2            Sam Mendes                   602.0  200074175.0
# 3     Christopher Nolan                   813.0  448130642.0
# 5        Andrew Stanton                   462.0   73058679.0
# ...                 ...                     ...          ...
# 5033      Shane Carruth                   143.0     424760.0
# 5034   Neill Dela Llana                    35.0      70071.0
# 5035   Robert Rodriguez                    56.0    2040920.0
# 5037       Edward Burns                    14.0       4584.0
# 5042           Jon Gunn                    43.0      85222.0
#
#                                    genres     actor_1_name  \
# 0         Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1                Action|Adventure|Fantasy      Johnny Depp
# ...

# %%
# Write code for repeating subtask 2 here
#duplicate entry of The Avengers movie is removed
top10=movies.sort_values(by=['profit'],ascending=False).head(10) 
top10
#Checkpoint 2- two movies directed by James Cameron present in the list
# Out:
#           director_name  num_critic_for_reviews        gross  \
# 0         James Cameron                   723.0  760505847.0
# 29      Colin Trevorrow                   644.0  652177271.0
# 26        James Cameron                   315.0  658672302.0
# 3024       George Lucas                   282.0  460935665.0
# 3080   Steven Spielberg                   215.0  434949459.0
# 17          Joss Whedon                   703.0  623279547.0
# 509        Roger Allers                   186.0  422783777.0
# 240        George Lucas                   320.0  474544677.0
# 66    Christopher Nolan                   645.0  533316061.0
# 439           Gary Ross                   673.0  407999255.0
#
#                                         genres         actor_1_name  \
# 0              Action|Adventure|Fantasy|Sci-Fi          CCH Pounder
# 29            Action|Adventure|Sci-Fi|Thriller  Bryce Dallas Howard
# 26                               Drama|Romance    Leonardo DiCaprio
# ...

# %% [markdown]
# **Checkpoint 2:** You might spot two movies directed by `James Cameron` in the list.

# %% [markdown]
# -  ### Subtask 3.4: Find IMDb Top 250
#
#     1. Create a new dataframe `IMDb_Top_250` and store the top 250 movies with the highest IMDb Rating (corresponding to the column: `imdb_score`). Also make sure that for all of these movies, the `num_voted_users` is greater than 25,000.
# Also add a `Rank` column containing the values 1 to 250 indicating the ranks of the corresponding films.
#     2. Extract all the movies in the `IMDb_Top_250` dataframe which are not in the English language and store them in a new dataframe named `Top_Foreign_Lang_Film`.

# %%
#first to observe num_votes_users greater than 25000
Voted_Users=movies.loc[(movies.num_voted_users>25000),:]
Voted_Users
# Out:
#           director_name  num_critic_for_reviews        gross  \
# 0         James Cameron                   723.0  760505847.0
# 1        Gore Verbinski                   302.0  309404152.0
# 2            Sam Mendes                   602.0  200074175.0
# 3     Christopher Nolan                   813.0  448130642.0
# 5        Andrew Stanton                   462.0   73058679.0
# ...                 ...                     ...          ...
# 4977    Morgan Spurlock                   193.0   11529368.0
# 5008        Kevin Smith                   136.0    3151130.0
# 5012         David Ayer                   233.0   10499968.0
# 5033      Shane Carruth                   143.0     424760.0
# 5035   Robert Rodriguez                    56.0    2040920.0
#
#                                    genres     actor_1_name  \
# 0         Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1                Action|Adventure|Fantasy      Johnny Depp
# ...

# %%
# Write your code for extracting the top 250 movies as per the IMDb score here. Make sure that you store it in a new dataframe and name that dataframe as 'IMDb_Top_250'
#Based on Voted_Users data store the top 250 movies in new dataframe IMDb_Top_250 which has more IMDb_Score of movies with descending order.
IMDb_Top_250= Voted_Users.sort_values(by=['imdb_score'],ascending=False).head(250)
IMDb_Top_250
# Out:
#              director_name  num_critic_for_reviews        gross  \
# 1937        Frank Darabont                   199.0   28341469.0
# 3466  Francis Ford Coppola                   208.0  134821952.0
# 2837  Francis Ford Coppola                   149.0   57300000.0
# 66       Christopher Nolan                   645.0  533316061.0
# 4498          Sergio Leone                   181.0    6100000.0
# ...                    ...                     ...          ...
# 4931           John Carney                   232.0    9437933.0
# 2605               Ang Lee                   287.0  128067808.0
# 3029      David O. Russell                   410.0   93571803.0
# 2177            Tim Burton                   111.0   56362352.0
# 2487          George Cukor                    82.0   72000000.0
#
#                             genres    actor_1_name  \
# 1937                   Crime|Drama  Morgan Freeman
# 3466                   Crime|Drama       Al Pacino
# ...

# %%
#Created RANK column based on highest IMDb_Scoreand & IMDb_Top_250 dataframe in desc order of first 250 movies.
IMDb_Top_250['Rank']=range(1,251) 
IMDb_Top_250
# Out:
#              director_name  num_critic_for_reviews        gross  \
# 1937        Frank Darabont                   199.0   28341469.0
# 3466  Francis Ford Coppola                   208.0  134821952.0
# 2837  Francis Ford Coppola                   149.0   57300000.0
# 66       Christopher Nolan                   645.0  533316061.0
# 4498          Sergio Leone                   181.0    6100000.0
# ...                    ...                     ...          ...
# 4931           John Carney                   232.0    9437933.0
# 2605               Ang Lee                   287.0  128067808.0
# 3029      David O. Russell                   410.0   93571803.0
# 2177            Tim Burton                   111.0   56362352.0
# 2487          George Cukor                    82.0   72000000.0
#
#                             genres    actor_1_name  \
# 1937                   Crime|Drama  Morgan Freeman
# 3466                   Crime|Drama       Al Pacino
# ...

# %%
# Write your code to extract top foreign language films from 'IMDb_Top_250' here
#top foreign language movies which are not in English language from IMDb_Top_250 dataframe.
Top_Foreign_Lang_Film = IMDb_Top_250.loc[(IMDb_Top_250.language != 'English'),:]  
Top_Foreign_Lang_Film 
#Checkpoint3 - Veer_Zaara aavailable in dataset.
# Out:
#                          director_name  num_critic_for_reviews        gross  \
# 4498                      Sergio Leone                   181.0    6100000.0
# 4747                    Akira Kurosawa                   153.0     269061.0
# 4029                Fernando Meirelles                   214.0    7563397.0
# 2373                    Hayao Miyazaki                   246.0   10049886.0
# 4259  Florian Henckel von Donnersmarck                   215.0   11284657.0
# 4921                      Majid Majidi                    46.0     925402.0
# 2323                    Hayao Miyazaki                   174.0    2298191.0
# 2970                 Wolfgang Petersen                    96.0   11433134.0
# 4105                    Chan-wook Park                   305.0    2181290.0
# 4659                    Asghar Farhadi                   354.0    7098492.0
# 1329                    S.S. Rajamouli                    44.0    6498000.0
# ...

# %% [markdown]
# **Checkpoint 3:** Can you spot `Veer-Zaara` in the dataframe?

# %% [markdown]
# - ### Subtask 3.5: Find the best directors
#
#     1. Group the dataframe using the `director_name` column.
#     2. Find out the top 10 directors for whom the mean of `imdb_score` is the highest and store them in a new dataframe `top10director`.  Incase of a tie in IMDb score between two directors, sort them alphabetically.

# %%
DirectorsName=movies.groupby(['director_name'])  #gorup the dataframe using director_name in new dataframe DirectorsName
DirectorsName

# %%
top10director=DirectorsName['imdb_score'].mean().reset_index().sort_values(by=['imdb_score','director_name'],ascending=[False,True]).head(10)
top10director  
#below are top 10 directors with mean of imdb_score is highest and sttore them in new dataframe top10director.
#sort them ascending order of director name as there are tie between IMDb score. 
#Here convert series into dataframe using reset_index() method.
# Out:
#               director_name  imdb_score
# 216         Charles Chaplin    8.600000
# 1675              Tony Kaye    8.600000
# 45         Alfred Hitchcock    8.500000
# 302         Damien Chazelle    8.500000
# 1017           Majid Majidi    8.500000
# 1440             Ron Fricke    8.500000
# 1498           Sergio Leone    8.433333
# 260       Christopher Nolan    8.425000
# 103          Asghar Farhadi    8.400000
# 1035  Marius A. Markevicius    8.400000

# %%
# Write your code for extracting the top 10 directors here
#sort top10director name and use drop value True to sort from index 0-9.
top10director.reset_index(drop=True) 
#Checkpoint 4- Damien Chazelle present in the directors list
# Out:
#            director_name  imdb_score
# 0        Charles Chaplin    8.600000
# 1              Tony Kaye    8.600000
# 2       Alfred Hitchcock    8.500000
# 3        Damien Chazelle    8.500000
# 4           Majid Majidi    8.500000
# 5             Ron Fricke    8.500000
# 6           Sergio Leone    8.433333
# 7      Christopher Nolan    8.425000
# 8         Asghar Farhadi    8.400000
# 9  Marius A. Markevicius    8.400000

# %% [markdown]
# **Checkpoint 4:** No surprises that `Damien Chazelle` (director of Whiplash and La La Land) is in this list.

# %% [markdown]
# -  ### Subtask 3.6: Find popular genres
#
# You might have noticed the `genres` column in the dataframe with all the genres of the movies seperated by a pipe (`|`). Out of all the movie genres, the first two are most significant for any film.
#
# 1. Extract the first two genres from the `genres` column and store them in two new columns: `genre_1` and `genre_2`. Some of the movies might have only one genre. In such cases, extract the single genre into both the columns, i.e. for such movies the `genre_2` will be the same as `genre_1`.
# 2. Group the dataframe using `genre_1` as the primary column and `genre_2` as the secondary column.
# 3. Find out the 5 most popular combo of genres by finding the mean of the gross values using the `gross` column and store them in a new dataframe named `PopGenre`.

# %%
# Write your code for extracting the first two genres of each movie here
first=movies['genres'].apply(lambda a: pd.Series(a.split('|'))) #Extracting first two Genres which are separated by | and use apply() method.
movies['genre_1']=first[0]  #creating genre_1 column
movies['genre_2']=first[1]  #creating genre_2 column
movies
# Out:
#           director_name  num_critic_for_reviews        gross  \
# 0         James Cameron                   723.0  760505847.0
# 1        Gore Verbinski                   302.0  309404152.0
# 2            Sam Mendes                   602.0  200074175.0
# 3     Christopher Nolan                   813.0  448130642.0
# 5        Andrew Stanton                   462.0   73058679.0
# ...                 ...                     ...          ...
# 5033      Shane Carruth                   143.0     424760.0
# 5034   Neill Dela Llana                    35.0      70071.0
# 5035   Robert Rodriguez                    56.0    2040920.0
# 5037       Edward Burns                    14.0       4584.0
# 5042           Jon Gunn                    43.0      85222.0
#
#                                    genres     actor_1_name  \
# 0         Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1                Action|Adventure|Fantasy      Johnny Depp
# ...

# %%
#some movies has only 1 genre , extract sinple genre in both new columns.
movies.loc[pd.isnull(movies['genre_2']), ['genre_2']] = movies['genre_1']  
movies.genre_1  #genre_1 data
# Out:
# 0            Action
# 1            Action
# 2            Action
# 3            Action
# 5            Action
#            ...
# 5033          Drama
# 5034       Thriller
# 5035         Action
# 5037         Comedy
# 5042    Documentary
# Name: genre_1, Length: 3856, dtype: object

# %%
movies.genre_2    #genre_2 data
# Out:
# 0         Adventure
# 1         Adventure
# 2         Adventure
# 3          Thriller
# 5         Adventure
#            ...
# 5033         Sci-Fi
# 5034       Thriller
# 5035          Crime
# 5037          Drama
# 5042    Documentary
# Name: genre_2, Length: 3856, dtype: object

# %%
movies_by_segment = movies.groupby(['genre_1','genre_2'])  # Write your code for grouping the dataframe here
movies_by_segment  #group the dataframe genre_1 is primary and genre_2 is secondary column

# %%
PopGenre = movies_by_segment['gross'].mean().sort_values(ascending=False).head(5)  # Write your code for getting the 5 most popular combo of genres here
PopGenre  
#using above genre_1 and genre_2 , find the mean of gross value column and store in new dataframe PopGenre
#Checkpoint 5- Family from genre_1 and Sci-Fi from genre_2 result achieved.
# Out:
# genre_1    genre_2
# Family     Sci-Fi       4.349495e+08
# Adventure  Sci-Fi       2.286278e+08
#            Family       1.189195e+08
#            Animation    1.169985e+08
# Action     Adventure    1.095955e+08
# Name: gross, dtype: float64

# %% [markdown]
# **Checkpoint 5:** Well, as it turns out. `Family + Sci-Fi` is the most popular combo of genres out there!

# %% [markdown]
# -  ### Subtask 3.7: Find the critic-favorite and audience-favorite actors
#
#     1. Create three new dataframes namely, `Meryl_Streep`, `Leo_Caprio`, and `Brad_Pitt` which contain the movies in which the actors: 'Meryl Streep', 'Leonardo DiCaprio', and 'Brad Pitt' are the lead actors. Use only the `actor_1_name` column for extraction. Also, make sure that you use the names 'Meryl Streep', 'Leonardo DiCaprio', and 'Brad Pitt' for the said extraction.
#     2. Append the rows of all these dataframes and store them in a new dataframe named `Combined`.
#     3. Group the combined dataframe using the `actor_1_name` column.
#     4. Find the mean of the `num_critic_for_reviews` and `num_users_for_review` and identify the actors which have the highest mean.
#     5. Observe the change in number of voted users over decades using a bar chart. Create a column called `decade` which represents the decade to which every movie belongs to. For example, the  `title_year`  year 1923, 1925 should be stored as 1920s. Sort the dataframe based on the column `decade`, group it by `decade` and find the sum of users voted in each decade. Store this in a new data frame called `df_by_decade`.

# %%
# Write your code for creating three new dataframes here
# Include all movies in which Meryl_Streep is the lead actor using actor_1_name column
Meryl_Streep = movies.loc[(movies.actor_1_name=='Meryl Streep'),:]
Meryl_Streep
# Out:
#        director_name  num_critic_for_reviews        gross  \
# 410     Nancy Meyers                   187.0  112703470.0
# 1106   Curtis Hanson                    42.0   46815748.0
# 1204     Nora Ephron                   252.0   94125426.0
# 1408   David Frankel                   208.0  124732962.0
# 1483  Robert Redford                   227.0   14998070.0
# 1575  Sydney Pollack                    66.0   87100000.0
# 1618   David Frankel                   234.0   63536011.0
# 1674   Carl Franklin                    64.0   23209440.0
# 1925  Stephen Daldry                   174.0   41597830.0
# 2781  Phyllida Lloyd                   331.0   29959436.0
# 3135   Robert Altman                   211.0   20338609.0
#
#                                genres  actor_1_name  \
# 410              Comedy|Drama|Romance  Meryl Streep
# 1106  Action|Adventure|Crime|Thriller  Meryl Streep
# 1204          Biography|Drama|Romance  Meryl Streep
# 1408             Comedy|Drama|Romance  Meryl Streep
# ...

# %%
# Include all movies in which Leo_Caprio is the lead actor using actor_1_name column
Leo_Caprio = movies.loc[(movies.actor_1_name=='Leonardo DiCaprio'),:] 
Leo_Caprio
# Out:
#               director_name  num_critic_for_reviews        gross  \
# 26            James Cameron                   315.0  658672302.0
# 50             Baz Luhrmann                   490.0  144812796.0
# 97        Christopher Nolan                   642.0  292568851.0
# 179   Alejandro G. Iñárritu                   556.0  183635922.0
# 257         Martin Scorsese                   267.0  102608827.0
# 296       Quentin Tarantino                   765.0  162804648.0
# 307            Edward Zwick                   166.0   57366262.0
# 308         Martin Scorsese                   606.0  116866727.0
# 326         Martin Scorsese                   233.0   77679638.0
# 361         Martin Scorsese                   352.0  132373442.0
# 452         Martin Scorsese                   490.0  127968405.0
# 641            Ridley Scott                   238.0   39380442.0
# 911        Steven Spielberg                   194.0  164435221.0
# ...

# %%
# Include all movies in which Brad_Pitt is the lead actor using actor_1_name column
Brad_Pitt = movies.loc[(movies.actor_1_name=='Brad Pitt'),:] 
Brad_Pitt
# Out:
#               director_name  num_critic_for_reviews        gross  \
# 101           David Fincher                   362.0  127490802.0
# 147       Wolfgang Petersen                   220.0  133228348.0
# 254       Steven Soderbergh                   198.0  125531634.0
# 255              Doug Liman                   233.0  186336103.0
# 382              Tony Scott                   142.0      26871.0
# 400       Steven Soderbergh                   186.0  183405771.0
# 470              David Ayer                   406.0   85707116.0
# 611     Jean-Jacques Annaud                    76.0   37901509.0
# 683           David Fincher                   315.0   37023395.0
# 792         Patrick Gilmore                    98.0   26288320.0
# 940             Neil Jordan                   120.0  105264608.0
# 1490        Terrence Malick                   584.0   13303319.0
# 1722         Andrew Dominik                   273.0    3904982.0
# ...

# %%
# Write your code for combining the three dataframes here
#append all the rows and store in new dataframe Combined , here I used concat() method of pandas to combine all the above df's.
Combined=pd.concat([Meryl_Streep,Leo_Caprio,Brad_Pitt])  
Combined
# Out:
#               director_name  num_critic_for_reviews        gross  \
# 410            Nancy Meyers                   187.0  112703470.0
# 1106          Curtis Hanson                    42.0   46815748.0
# 1204            Nora Ephron                   252.0   94125426.0
# 1408          David Frankel                   208.0  124732962.0
# 1483         Robert Redford                   227.0   14998070.0
# 1575         Sydney Pollack                    66.0   87100000.0
# 1618          David Frankel                   234.0   63536011.0
# 1674          Carl Franklin                    64.0   23209440.0
# 1925         Stephen Daldry                   174.0   41597830.0
# 2781         Phyllida Lloyd                   331.0   29959436.0
# 3135          Robert Altman                   211.0   20338609.0
# 26            James Cameron                   315.0  658672302.0
# 50             Baz Luhrmann                   490.0  144812796.0
# ...

# %%
# Write your code for grouping the combined dataframe here
Combined_Actor_Name=Combined.groupby('actor_1_name')   # grouping the Combined dataframe using actor_1_name and store it in new dataframe Combined_Actor_Name
Combined_Actor_Name

# %%
# Write the code for finding the mean of critic reviews and audience reviews here
Mean_Of_Num_Critic_Reviews=Combined_Actor_Name['num_critic_for_reviews'].mean().sort_values(ascending=False)
Mean_Of_Num_Critic_Reviews  #find mean of critics reviews using column num_critic_for_reviews adn sort it desc order.
# Out:
# actor_1_name
# Leonardo DiCaprio    330.190476
# Brad Pitt            245.000000
# Meryl Streep         181.454545
# Name: num_critic_for_reviews, dtype: float64

# %%
Mean_Of_User_Reviews=Combined_Actor_Name['num_user_for_reviews'].mean().sort_values(ascending=False)
Mean_Of_User_Reviews  #find mean of users/audiences reviews with using num_user_for_reviews and sorted in desc.
#Checkpoint 6- Leonardo is at top in both critics as well as users reviews.
# Out:
# actor_1_name
# Leonardo DiCaprio    914.476190
# Brad Pitt            742.352941
# Meryl Streep         297.181818
# Name: num_user_for_reviews, dtype: float64

# %% [markdown]
# **Checkpoint 6:** `Leonardo` has aced both the lists!

# %%
# Write the code for calculating decade here
movies['decade'] = movies['title_year']//10*10   #store title_year data in new dataframe decade
movies
# Out:
#           director_name  num_critic_for_reviews        gross  \
# 0         James Cameron                   723.0  760505847.0
# 1        Gore Verbinski                   302.0  309404152.0
# 2            Sam Mendes                   602.0  200074175.0
# 3     Christopher Nolan                   813.0  448130642.0
# 5        Andrew Stanton                   462.0   73058679.0
# ...                 ...                     ...          ...
# 5033      Shane Carruth                   143.0     424760.0
# 5034   Neill Dela Llana                    35.0      70071.0
# 5035   Robert Rodriguez                    56.0    2040920.0
# 5037       Edward Burns                    14.0       4584.0
# 5042           Jon Gunn                    43.0      85222.0
#
#                                    genres     actor_1_name  \
# 0         Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1                Action|Adventure|Fantasy      Johnny Depp
# ...

# %%
# Write your code for creating the data frame df_by_decade here 
 #find the sum of each decade and store them in df_by_decade new dataframe with desc order.
df_by_decade=movies.groupby('decade')['num_voted_users'].sum().sort_values(ascending=False)
df_by_decade
# Out:
# decade
# 2000.0    170908676
# 2010.0    120640994
# 1990.0     69735679
# 1980.0     19987476
# 1970.0      8524102
# 1960.0      2983442
# 1930.0       804839
# 1950.0       678336
# 1940.0       230838
# 1920.0       116392
# Name: num_voted_users, dtype: int64

# %%
# Write your code for plotting number of voted users vs decade
sns.set_style("white")
plt.figure(figsize=(12, 6))   # increase figure size 
sns.barplot(x ='decade', y ='num_voted_users', data = movies , palette = 'spring')
plt.yscale('log') #use log to observe distribution of plot in better way 
plt.show()        #outliers - decade 2000 has max num voted and decade 1920 has less.
